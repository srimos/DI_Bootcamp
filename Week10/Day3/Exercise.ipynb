# %%
import matplotlib.pyplot as plt
# Creating a figure and axes
fig, ax = plt.subplots()  # Create a figure containing a single axes

# %%
import matplotlib.pyplot as plt
# Creating a figure and axes
fig, ax = plt.subplots()  # Create a figure containing a single axes
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-10, 10, 100)
y = x ** 2
fig, ax = plt.subplots() 
ax.plot(x,y,color='red',linestyle='--',marker='o',label='red line')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()  
ax.plot([1,1.5,2,2.5,3,3.5],[2,3,1,4,1,3])

# %%
data=[150,100,155,160,166,179,175,173]
data = np.random.randn(1000)

fig, ax = plt.subplots()
ax.hist(data, bins=3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 20)
y1 = x ** 2
y2 = x ** 1.5

# Create a line plot of y1 against x.
fig, ax = plt.subplots() 
ax.plot(x,y1)

# Create a scatter plot of y2 against x..
fig, ax = plt.subplots() 
ax.scatter(x,y2)
fig.savefig('my_plot.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 20)
y1 = x ** 2
y2 = x ** 1.5

# Create a line plot of y1 against x with a red dashed line and circular markers. Label it y = x^2.
fig, ax = plt.subplots() 
ax.plot(x,y1,color='red',linestyle='--',marker='o',label='y=x^2')
ax.legend()
plt.show()

# Create a line plot of y2 against x with a blue dotted line and square markers. Label it y = x^1.5.
fig, ax = plt.subplots() 
ax.plot(x,y1,color='blue',linestyle=':',marker='s',label='y=x^1.5')
ax.set(title='My Styled Plot', xlabel='x', ylabel='y')
ax.legend()
plt.show()
fig.savefig('my_styled_plot.png')

# %%
fig,axs=plt.subplots(2,1) #array of 2 rows and 1 column
axs

axs[0].plot([1,2,3,4],[2,5,3,7])
axs[1].scatter([3,4,5,6],[9,5,8,3])

# %%
fig,axs=plt.subplots(2,2) #array of 2 rows and 2 column
axs

axs[0][0].plot([1,2,3,4],[2,5,3,7])
axs[1][1].scatter([3,4,5,6],[9,5,8,3])

# %%
import numpy as np
import matplotlib.pyplot as plt
fig,axs=plt.subplots(2,2) #array of 2 rows and 1 column
axs
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

axs[0][0].plot(x,y,label='y=x')
axs[0][1].plot(x,-y)
axs[1][0].plot(x,y**2)
axs[1][1].plot(x,(-y)**2)

axs[0][0].set_ylim(-4, 4)
axs[0][0].annotate('local max', xy=(1.2, 1), xytext=(1.5, 2.5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )
axs[0][0].annotate('local min', xy=(2.1, -1), xytext=(3, -2),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )
axs[0][0].legend(title='Legend',loc='upper right',shadow=True)

# %%
# Importing necessary modules
from mpl_toolkits.mplot3d import Axes3D  # Enables 3D plotting
import numpy as np
import matplotlib.pyplot as plt

# Initialize a new figure
fig = plt.figure()

# Create a 3D axis object
ax = plt.axes(projection="3d")

# Define data for the line
z_line = np.linspace(0, 15, 1000)
x_line = np.cos(z_line)
y_line = np.sin(z_line)
# Plot the line
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.plot3D(x_line, y_line, z_line, 'gray')

# Define data for the points
z_points = 15 * np.random.random(100)
x_points = np.cos(z_points) + 0.1 * np.random.randn(100)
y_points = np.sin(z_points) + 0.1 * np.random.randn(100)

# Plot the points, with color determined by z_points and colormap 'hsv'
ax.scatter3D(x_points, y_points, z_points, c=z_points, cmap='hsv');

plt.show()
