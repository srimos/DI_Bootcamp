# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('titanic.csv', encoding='utf-8')
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(subset='Age',inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         2
# dtype: int64

# %%
df['Cabin'].fillna('NA',inplace=True)
df.drop(subset='Embarked',inplace=True)
df.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 df['Cabin'].fillna('NA',inplace=True)
# ----> 2 df.drop(subset='Embarked', inplace=True)
#       3 df.isna().sum()
#
# TypeError: DataFrame.drop() got an unexpected keyword argument 'subset'

# %%
df['Age']=df['Age'].astype(int)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female   39      0
# 886                              Montvila, Rev. Juozas    male   27      0
# 887                       Graham, Miss. Margaret Edith  female   19      0
# 889                              Behr, Mr. Karl Howell    male   26      0
# 890                                Dooley, Mr. Patrick    male   32      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500    NA        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250    NA        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500    NA        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250    NA        Q
# 886      0            211536  13.0000    NA        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500    NA        Q
#
# [714 rows x 12 columns]

# %%
df.to_csv('titanic_cleaned.csv',index=False)

# %%
data=df['Sex'].value_counts()
plt.figure(figsize=(8,8))
fig,ax=plt.subplots()
ax.pie(data,labels=data.index,startangle=90,colors=['#ff0000','#0000ff'])
ax.legend()
ax.set_title('Males vs Females on Titanic')
# Out:
# Text(0.5, 1.0, 'Males vs Females on Titanic')

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Age'],bins=4,kde=True,color='blue')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
bins=[0,20,40,60,80]
labels=['0-20','21-40','41-60','61-80']
df['Age_bin']=pd.cut(df['Age'], bins=bins,labels=labels)
df['Age_bin'].value_counts()
# Out:
# Age_bin
# 21-40    386
# 0-20     173
# 41-60    126
# 61-80     22
# Name: count, dtype: int64

# %%
survival_by_gender=df.groupby('Sex')['Survived'].value_counts().unstack()
survival_by_gender.columns=['Did not survive','Survived']
survival_by_gender
# Out:
#         Did not survive  Survived
# Sex
# female               64       197
# male                360        93

# %%
plt.figsize=(10,10)
plt.title['Survival on Titanic']
survival_by_gender.plot(kind='bar',stacked=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 plt.figsize=(10,10)
# ----> 2 plt.title['Survival on Titanic']
#       3 survival_by_gender.plot(kind='bar',stacked=True)
#       4 plt.show()
#
# TypeError: 'function' object is not subscriptable

# %%
df=pd.get_dummies(df,columns=['Sex'])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   38      1      0
# 2                             Heikkinen, Miss. Laina   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   35      1      0
# 4                           Allen, Mr. William Henry   35      0      0
#
#              Ticket     Fare Cabin Embarked Age_bin  Sex_female  Sex_male
# 0         A/5 21171   7.2500    NA        S   21-40       False      True
# 1          PC 17599  71.2833   C85        C   21-40        True     False
# 2  STON/O2. 3101282   7.9250    NA        S   21-40        True     False
# 3            113803  53.1000  C123        S   21-40        True     False
# 4            373450   8.0500    NA        S   21-40       False      True
